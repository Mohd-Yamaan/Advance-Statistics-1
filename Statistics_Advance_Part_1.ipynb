# %% [markdown]
# 1. What is a random variable in probability theory?
#
# **Answer -- A set of possible values from a random expriment that is called a random variable.
#
# Example :  Tossing a coin. Expriment is random and outcomes will be random. outcomes is either head or tail.

# %% [markdown]
# 2. What are the types of random variables?
# **Answer** -- There are two types of Random variables
#
# 1. Discrete Random Variable
#
# 2. Continious Random Variable
#
# Discrete random variable is a type of variable that can take only a specific and countable values
#
# Example:
#
# like 2,3,4,5,6
#
# Continuous random variable is a type of variable that can take an any value in a range
#
# Example:
#
# Like 2.5, 3.76, 8.001 — it can include decimals or fractions, not just whole numbers.

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions?
#
# **Answer -- ** The difference between the discrete and continious distributon.
#
# A discrete distribution shows the probability of each value a discrete random variable can take.
#
# A continuous distribution shows the probability of values that a continuous random variable can take.
#
# A discrete distribution deals with values you can count one by one, like 0, 1, 2, 3. It shows the probability of each value using a table. For example, the number of heads when tossing 2 coins is a discrete distribution.
#
# A continuous distribution deals with values that can be any number in a range, including decimals, like 2.5 or 3.76. It uses a smooth curve (not a table) to show probabilities. For example, people's height or weight follows a continuous distribution.

# %% [markdown]
# 4. What are probability distribution functions (PDF)?
#
# **Answer --** PMF means Probability Mass Function it is used for Discrete random variables
#
# PMF tell us the probability of each possible value of the discrete variable.
#
# Example: if you roll a fair dice the pmf is
#
# P( X = 1) = 1/6, P( X = 2) = 1/6, P( X = 3) = 1/6, P( X = 4) = 1/6,
#
#  P( X = 5) = 1/6, P( X = 6) = 1/6
#
# The Probability of PMF is always Between 0 to 1
#
# The total of all probabilities = 1

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)
#
# **Answer --** CDF means Cumalative distribution function(CDF)
#
# It shows the probability that a random variable 𝑋 is less than or equal to a certain value 𝑥
#
# F(x)=P(X≤x)
#
# PMF (Probability Mass Function)
# Used for discrete random variables.
#
# Gives the probability of the variable taking exactly one value.
#
# Example:
#
# P(X=2)=0.3 means the chance of X being exactly 2 is 0.3.
#
# CDF (Cumulative Distribution Function)
# Used for both discrete and continuous random variables.
#
# Gives the probability that the variable is less than or equal to a value.
#
# Example:
#
# F(2)=P(X≤2)=0.7 means the chance of X being 2 or less is 0.7.

# %% [markdown]
# 6. What is a discrete uniform distribution?
#
# **Answer** First I explain the Uniform distribution then discrete uniform sistribution?
#
# Uniform distribution is a type of probability distribution the probability in which all the outcomes is Equally likely.
#
# **Discrete uniform distribution** -- In a Discrete random variable the outcomes are discrete and have a same probability.
#
# Example: Rolling a dice
#
#          Tossing a coin
#
#          Picking a card from well suffled card

# %% [markdown]
# 7. What are the key properties of a Bernoulli distribution?
#
# **Answer --** The Key properties of a bernoulli distribution.
#
# * the number of trail(n) is only one.
#
# * There are only two possible outcomes succes or faliure.
#
# * The code of Sucess is (1) or Failure is (0).

# %% [markdown]
# 8. What is the binomial distribution, and how is it used in probability?
#
# **Answer -- ** The Binomial distribution is a type of probability distribution where there are (n) number of independent trials, and each trial has only two outcomes: success or failure.
#
#  Success (like yes, win, or head)
#  Failure (like no, lose, or tail)
#
#  How is it used in probability?
#
# It is used when:
#
# You repeat the same experiment multiple times.
#
# You want to know the probability of getting a certain number of successes.

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied?
#
# **Answer** -- poisson distribution is probability distribution that discribe number or times an event happen in a fixed interval of a time or pace when events is independently and at a constant average rate.
#
# key points
#
# * Event are rare or happen randomly
#
# * The time or space is fixed
#
# * The events occur independently
#
#  Where is it applied?
# It is used to model real-life situations like:
#
# Number of calls received by a call center in 1 hour
#
# Number of accidents on a road in a day
#
# Number of emails received in a day
#
# Number of errors found per page in a book
#
# Number of customers arriving at a store per minute

# %% [markdown]
# 1o. What is a continuous uniform distribution?
#
# **Answer --** A continuous uniform distribution is a type of probability distribution where all the values between a starting and ending point are equally likely to happen. This means there is no value in that range that is more likely than others.
#
# For example, if a train can arrive any time between 10:00 AM to 10:30 AM, and it is equally likely to come at any time in that range, then that is a continuous uniform distribution.
#
# This kind of distribution is used when we are dealing with continuous data like time, distance, or temperature.

# %% [markdown]
# 11. What are the characteristics of a normal distribution?
#
# **Answer --** A normal distribution is a very important probability distribution that looks like a symmetric bell-shaped curve. Here are some key characteristics:
#
# * It is symmetrical around the mean, so both sides of the curve are mirror images.
#
# * The mean, median, and mode are all the same value and located at the center of the distribution.
#
# * Most of the data is concentrated near the mean, and as you move further away, the probabilities get smaller.
#
# * The curve never touches the horizontal axis but gets closer and closer to it (it extends to infinity in both directions).
#
# * About 68% of the data falls within 1 standard deviation from the mean, 95% within 2 standard deviations, and 99.7% within 3 standard deviations — this is called the empirical rule.

# %% [markdown]
# 12. What is the standard normal distribution, and why is it important
#
# **Answer --** The standard normal distribution is a special type of normal distribution. It has a mean of 0 and a standard deviation of 1. This means it's centered at zero, and the spread of the data is fixed.
#
# It's important because it helps us easily calculate probabilities and work with any normal distribution by converting it into this standard form. This process is called standardization or z-score transformation.
#
# By using the standard normal distribution, we can find probabilities and compare different normal distributions, even if they have different means and standard deviations.

# %% [markdown]
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# **Answer --** The CLT (central limit theorum) stand for if you have a population woth a mean and standard divation and take sufficient large no. of random sample from the population which replacement them the  distribution of sample means ill be approximately Normally distributed.

# %% [markdown]
# 14. How does the Central Limit Theorem relate to the normal distribution)
#
#
# **Answer --** The Central Limit Theorem (CLT) says that when we take many random samples from any population, the distribution of the sample means will become normal, even if the original data is not normal — if the sample size is large.
#
#  So, CLT helps us use the normal distribution for making predictions and confidence intervals.

# %% [markdown]
# 15. What is the application of Z statistics in hypothesis testing)
#
# **Answer --** Z-statistics is used when sample size is large and population standard deviation is known.
# It helps test if the sample mean is significantly different from the population mean.
#
# Example: Used in Z-test to accept or reject null hypothesis.

# %% [markdown]
# 16. How do you calculate a Z-score, and what does it represent)
#
#
# **Answer --** Z-score represents how many standard deviations a value is away from the mean.
#
# Formula:
#
# Z-score = X - Mean/ STD
# ​
#
# It helps to know if a value is above or below the average, and by how much.

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics?
#
# **Answer --**
# Point Estimate:
#
# A point estimate is a single value used to guess a population parameter.
#
# **Example:** Sample mean is a point estimate of population mean.
#
# Interval Estimate:
#
# An interval estimate gives a range of values that likely contains the population parameter.
#
# **Example:** A confidence interval like 60 to 70.
#
#  18. What is the significance of confidence intervals in statistical analysis?
#
#  **Answer --** Confidence intervals show the range where the true population value is likely to lie, based on sample data.
#
# It gives an idea of accuracy — instead of just one estimate, it gives a range with a confidence level (like 95%).
#
# Example: "We are 95% confident that the true mean is between 50 and 60."

# %% [markdown]
# 19. What is the relationship between a Z-score and a confidence interval?
#
# **Answer --** A Z-score is used to calculate a confidence interval when the population standard deviation is known.

# %% [markdown]
# 20. How are Z-scores used to compare different distributions)
#
#
# **Answer --** Z-scores convert values from different distributions into a common scale (standard normal).
# This makes it easy to compare values even if the means and standard deviations are different.
#
# 📌 Example: You can compare test scores from two exams with different scoring systems using Z-scores.

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value.

# %%
import random

# import random variable
random_variable = random.randint(1, 6)
print(random_variable)
# Out:
# 3

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define parameters for discrete uniform distribution
low = 1   # min
high = 7  # maximum value (not included, so for 1–6 like a die)

# Create a range of values
x = np.arange(low, high)

# Get PMF values
pmf_values = randint.pmf(x, low, high)

# Plot PMF
plt.stem(x, pmf_values)
plt.xlabel('Values')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution (Die Roll)')
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(x, p):
    if x == 1:
        return p
    elif x == 0:
        return 1 - p
    else:
        return 0  # Not a valid Bernoulli outcome

# Example usage
print("P(X=1):", bernoulli_pdf(1, 0.7))  # Success
print("P(X=0):", bernoulli_pdf(0, 0.7))  # Failure
# Out:
# P(X=1): 0.7
# P(X=0): 0.30000000000000004

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram>

# %%
# Parameters
n = 10       # number of trials
p = 0.5      # probability of success
size = 1000  # number of simulations

data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=np.arange(0, n+2) - 0.5, edgecolor='black', density=True)
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.xticks(range(n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
λ = 4  # average rate (mean)
x = np.arange(0, 15)  # range of values

# Get the PMF (Probability Mass Function)
pmf_values = poisson.pmf(x, λ)

# Plot the PMF
plt.bar(x, pmf_values, color='skyblue', edgecolor='black')
plt.title("Poisson Distribution (λ = 4)")
plt.xlabel("Number of Events (x)")
plt.ylabel("Probability P(X = x)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the values of the discrete uniform distribution
values = np.arange(1, 11)  # For example, values from 1 to 10
prob = 1 / len(values)     # Equal probability for each value

# Calculate the CDF
cdf = np.cumsum([prob] * len(values))

# Plot the CDF
plt.step(values, cdf, where='post', label='CDF', color='blue')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('CDF of Discrete Uniform Distribution (1 to 10)')
plt.grid(True)
plt.ylim(0, 1.1)
plt.legend()
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 random values from a continuous uniform distribution between 0 and 1
data = np.random.uniform(low=0.0, high=1.0, size=1000)

# Plot histogram
plt.hist(data, bins=20, density=True, color='skyblue', edgecolor='black')
plt.title('Continuous Uniform Distribution (0 to 1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate 1000 data points from a normal distribution
# mean = 0, standard deviation = 1
data = np.random.normal(loc=0, scale=1, size=1000)

# Plot histogram
plt.hist(data, bins=30, color='lightgreen', edgecolor='black', density=True)
plt.title('Histogram of Simulated Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them>

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std = np.std(data)

    # Calculate Z-scores
    z_scores = (data - mean) / std

    # Plot the Z-scores
    plt.figure(figsize=(10, 5))
    plt.plot(z_scores, marker='o', linestyle='', color='blue')
    plt.axhline(0, color='green', linestyle='--', label='Mean (Z=0)')
    plt.title('Z-Scores of Dataset')
    plt.xlabel('Data Index')
    plt.ylabel('Z-Score')
    plt.grid(True)
    plt.legend()
    plt.show()

    return z_scores

# Example usage with random data
sample_data = np.random.normal(50, 10, 100)  # Mean=50, SD=10
z_scores = calculate_and_plot_z_scores(sample_data)

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Create a non-normal population (exponential distribution)
population = np.random.exponential(scale=2.0, size=100000)

# Step 2: Draw many samples and compute sample means
sample_means = []

sample_size = 30
num_samples = 1000

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size)
    sample_means.append(np.mean(sample))

# Step 3: Plot original population and sample means
plt.figure(figsize=(12, 5))

# Plot original non-normal distribution
plt.hist(population, bins=50, color='orange', edgecolor='black', density=True)
plt.title('Non-Normal Population (Exponential)')
plt.xlabel('Value')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# 15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define population parameters
mu = 50           # population mean
sigma = 10        # population standard deviation

# Step 2: Simulate multiple samples
sample_size = 30       # size of each sample (n ≥ 30 for CLT)
num_samples = 1000     # how many samples to take

sample_means = []

for _ in range(num_samples):
    sample = np.random.normal(mu, sigma, sample_size)  # draw sample from normal distribution
    sample_mean = np.mean(sample)                      # calculate sample mean
    sample_means.append(sample_mean)                   # store the mean

# Step 3: Plot the distribution of sample means
plt.figure(figsize=(8, 5))
plt.hist(sample_means, bins=30, edgecolor='black', color='skyblue', density=True)
plt.title('Distribution of Sample Means (CLT Verification)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.axvline(np.mean(sample_means), color='red', linestyle='dashed', label='Mean of Sample Means')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)5

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    # Generate values from -4 to 4
    x = np.linspace(-4, 4, 1000)

    # Calculate standard normal PDF (mean=0, std=1)
    y = norm.pdf(x, loc=0, scale=1)

    # Plot the curve
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='blue', label='Standard Normal Distribution')
    plt.title('Standard Normal Distribution (μ=0, σ=1)')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.axvline(0, color='red', linestyle='dashed', label='Mean = 0')
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal()

# %% [markdown]
# 17. Generate random variables and calculate their corresponding probabilities using the binomial distribution5

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

def binomial_example(n=10, p=0.5):
    # Step 1: Generate random binomial values
    random_data = np.random.binomial(n=n, p=p, size=1000)

    # Step 2: Calculate probability for 0 to n successes
    x = np.arange(0, n+1)
    probabilities = binom.pmf(x, n, p)  # PMF = Probability Mass Function

    # Step 3: Plot the binomial distribution
    plt.figure(figsize=(8, 5))
    plt.bar(x, probabilities, color='skyblue', edgecolor='black')
    plt.title(f'Binomial Distribution (n={n}, p={p})')
    plt.xlabel('Number of Successes')
    plt.ylabel('Probability')
    plt.grid(True, axis='y')
    plt.show()

    # Step 4: Print a few probabilities
    for k in range(0, n+1):
        print(f"P(X = {k}) = {probabilities[k]:.4f}")

# Example usage
binomial_example(n=10, p=0.5)
# Out:
# P(X = 0) = 0.0010
# P(X = 1) = 0.0098
# P(X = 2) = 0.0439
# P(X = 3) = 0.1172
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 6) = 0.2051
# P(X = 7) = 0.1172
# P(X = 8) = 0.0439
# P(X = 9) = 0.0098
# P(X = 10) = 0.0010

# %% [markdown]
# 18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std_dev):
    z = (x - mean) / std_dev
    return z

def plot_standard_normal_with_z(z_score):
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, 0, 1)  # Standard normal distribution

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal Curve', color='blue')

    # Shade area up to the z-score
    x_shade = np.linspace(-4, z_score, 1000)
    y_shade = norm.pdf(x_shade, 0, 1)
    plt.fill_between(x_shade, y_shade, color='orange', alpha=0.5, label=f'Area ≤ Z = {z_score:.2f}')

    # Draw vertical line at Z-score
    plt.axvline(z_score, color='red', linestyle='dashed', label=f'Z = {z_score:.2f}')

    plt.title('Standard Normal Distribution with Z-score')
    plt.xlabel('Z-value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example input
data_point = 75
mean = 70
std_dev = 5

# Step 1: Calculate Z-score
z = calculate_z_score(data_point, mean, std_dev)
print(f"Z-score for data point {data_point} is: {z:.2f}")

# Step 2: Plot and compare
plot_standard_normal_with_z(z)
# Out:
# Z-score for data point 75 is: 1.00

# %% [markdown]
# 19. Implement hypothesis testing using Z-statistics for a sample dataset5

# %%
import numpy as np
from scipy.stats import norm

# Step 1: Sample and Population Info
sample_mean = 98          # x̄
population_mean = 100     # μ (claimed mean)
sample_std = 10           # s
sample_size = 50          # n
alpha = 0.05              # significance level

# Step 2: Calculate Z-statistic
z = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
print(f"Z-statistic: {z:.2f}")

# Step 3: Calculate critical value for 2-tailed test
z_critical = norm.ppf(1 - alpha / 2)
print(f"Z-critical (±): ±{z_critical:.2f}")

# Step 4: Decision
if abs(z) > z_critical:
    print("Reject the null hypothesis: The claim may be incorrect.")
else:
    print("Fail to reject the null hypothesis: The claim seems reasonable.")
# Out:
# Z-statistic: -1.41
# Z-critical (±): ±1.96
# Fail to reject the null hypothesis: The claim seems reasonable.

# %% [markdown]
# 20. Create a confidence interval for a dataset using Python and interpret the result5

# %%
import numpy as np
import scipy.stats as stats

# Sample data (example: exam scores of 10 students)
data = [65, 70, 72, 68, 75, 80, 78, 85, 90, 88]

# Step 1: Calculate mean and standard error
mean = np.mean(data)
std_err = stats.sem(data)  # standard error of the mean

# Step 2: Set confidence level (let’s use 95%)
confidence = 0.95

# Step 3: Calculate confidence interval
ci = stats.t.interval(confidence, len(data)-1, loc=mean, scale=std_err)

# Step 4: Print results
print(f"Mean: {mean:.2f}")
print(f"95% Confidence Interval: {ci}")
# Out:
# Mean: 77.10
# 95% Confidence Interval: (np.float64(70.94211068886098), np.float64(83.25788931113901))

# %% [markdown]
# 21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Generate data from a normal distribution
np.random.seed(42)  # for consistent results
data = np.random.normal(loc=100, scale=15, size=50)  # mean=100, std=15, n=50

# Step 2: Calculate the mean and standard error
mean = np.mean(data)
std_err = stats.sem(data)

# Step 3: Set confidence level (e.g., 95%) and calculate CI
confidence = 0.95
ci = stats.t.interval(confidence, df=len(data)-1, loc=mean, scale=std_err)

# Step 4: Print results
print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: {ci}")
# Out:
# Sample Mean: 96.62
# 95% Confidence Interval: (np.float64(92.63770544287226), np.float64(100.59807739944353))

# %% [markdown]
# 22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Define parameters for the normal distribution
mean = 0      # center of the curve
std_dev = 1   # standard deviation (spread)

# Step 2: Generate x values
x = np.linspace(-4, 4, 1000)  # values from -4 to 4

# Step 3: Calculate the PDF values
pdf = norm.pdf(x, loc=mean, scale=std_dev)

# Step 4: Plot the PDF
plt.figure(figsize=(8, 4))
plt.plot(x, pdf, color='blue', label='Normal PDF')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Step 1: Define Poisson distribution parameters
mu = 3  # average rate (λ)

# Step 2: Define the range of x values (events)
x = np.arange(0, 11)  # values from 0 to 10

# Step 3: Calculate CDF values
cdf = poisson.cdf(x, mu)

# Step 4: Print some CDF values
for xi, cdf_val in zip(x, cdf):
    print(f"P(X ≤ {xi}) = {cdf_val:.4f}")

# Step 5: Plot CDF
plt.figure(figsize=(8, 4))
plt.step(x, cdf, where='post', label='Poisson CDF', color='green')
plt.title('CDF of Poisson Distribution (λ = 3)')
plt.xlabel('Number of Events (x)')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0498
# P(X ≤ 1) = 0.1991
# P(X ≤ 2) = 0.4232
# P(X ≤ 3) = 0.6472
# P(X ≤ 4) = 0.8153
# P(X ≤ 5) = 0.9161
# P(X ≤ 6) = 0.9665
# P(X ≤ 7) = 0.9881
# P(X ≤ 8) = 0.9962
# P(X ≤ 9) = 0.9989
# P(X ≤ 10) = 0.9997

# %% [markdown]
# 24. Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np

# Step 1: Define range a to b
a = 10
b = 20

# Step 2: Simulate 1000 random values from uniform distribution
np.random.seed(0)  # for reproducibility
data = np.random.uniform(a, b, 1000)

# Step 3: Calculate the expected value theoretically and from the sample
expected_theoretical = (a + b) / 2
expected_sample = np.mean(data)

# Step 4: Print the results
print(f"Theoretical Expected Value: {expected_theoretical}")
print(f"Sample Mean (Estimated Expected Value): {expected_sample:.2f}")
# Out:
# Theoretical Expected Value: 15.0
# Sample Mean (Estimated Expected Value): 14.96

# %% [markdown]
# 25. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Create two datasets
data1 = [12, 15, 14, 10, 18, 19, 17, 13, 16]
data2 = [5, 25, 10, 30, 2, 35, 1, 40, 3]

# Step 2: Calculate standard deviations
std1 = np.std(data1, ddof=1)  # sample standard deviation
std2 = np.std(data2, ddof=1)

# Step 3: Print the standard deviations
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Step 4: Visualize with a bar chart
labels = ['Dataset 1', 'Dataset 2']
std_values = [std1, std2]

plt.figure(figsize=(6, 4))
plt.bar(labels, std_values, color=['blue', 'orange'])
plt.title('Comparison of Standard Deviations')
plt.ylabel('Standard Deviation')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 2.93
# Standard Deviation of Dataset 2: 15.63
